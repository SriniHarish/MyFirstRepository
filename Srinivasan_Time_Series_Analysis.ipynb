# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/HP/Downloads/1650879577591_TATAMOTORS.csv", parse_dates = True, index_col="Date")

# %%
df.head()
# Out:
#            Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# Date
# 2000-01-03  TELCO     EQ      201.60  207.4  217.25  207.4  217.0  216.75
# 2000-01-04  TELCO     EQ      216.75  217.0  219.00  206.0  211.9  208.20
# 2000-01-05  TELCO     EQ      208.20  194.0  217.80  194.0  213.1  213.25
# 2000-01-06  TELCO     EQ      213.25  215.0  229.90  215.0  222.0  222.10
# 2000-01-07  TELCO     EQ      222.10  224.0  239.90  223.1  239.9  239.90
#
#               VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2000-01-03  214.28   676126  1.450000e+13     NaN                 NaN
# 2000-01-04  209.50   679215  1.420000e+13     NaN                 NaN
# 2000-01-05  210.33  1120951  2.360000e+13     NaN                 NaN
# 2000-01-06  225.29  1968998  4.440000e+13     NaN                 NaN
# 2000-01-07  236.32  2199431  5.200000e+13     NaN                 NaN
#
#             %Deliverble
# Date
# 2000-01-03          NaN
# 2000-01-04          NaN
# ...

# %%
df['Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot(subplots = True, figsize =(10,12))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
df_month = df.resample("M").mean()

# %%
fig, ax = plt.subplots(figsize=(10,6))

# %%
ax.bar(df_month['2016':].index,df_month.loc['2016':,"Volume"],width = 25, align = 'center')
# Out:
# <BarContainer object of 64 artists>

# %%
ax.bar(df_month['2021':].index,df_month.loc['2021':,"Volume"],width = 25, align = 'center')
# Out:
# <BarContainer object of 4 artists>

# %%
df.Low.diff(2).plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.High.diff(2).plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Change'] = df.Close.div(df.Close.shift())
df['Change'].plot(figsize=(10,6), fontsize = 16)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['2017']['Change'].plot(figsize=(10,6))
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_14588/1094941946.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017']['Change'].plot(figsize=(10,6))
# <AxesSubplot:xlabel='Date'>

# %%
df['2021']['Change'].plot(figsize=(10,6))
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_14588/895556365.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2021']['Change'].plot(figsize=(10,6))
# <AxesSubplot:xlabel='Date'>
